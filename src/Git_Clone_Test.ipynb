# %% [markdown]
# <a href="https://colab.research.google.com/github/Joovvhan/repository-for-colab/blob/master/src/Git_Clone_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os

# %%
os.listdir('drive/My Drive/Github')
# Out:
# []

# %%
os.chdir('drive/My Drive/Github')

# %%
os.mkdir('drive/My Drive/Github')

# %%
# !git clone https://github.com/Joovvhan/repository-for-colab.git
# Out:
# Cloning into 'repository-for-colab'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
os.chdir('repository-for-colab')

# %%
os.mkdir('data')

# %%
os.chdir('data')

# %%
# !git clone https://github.com/lucko515/speech-recognition-neural-network.git
# Out:
# Cloning into 'speech-recognition-neural-network'...
# remote: Enumerating objects: 37, done.
# remote: Total 37 (delta 0), reused 0 (delta 0), pack-reused 37
# Unpacking objects: 100% (37/37), done.

# %%
# !git clone https://github.com/udacity/AIND-VUI-Capstone.git
# Out:
# Cloning into 'AIND-VUI-Capstone'...
# remote: Enumerating objects: 134, done.
# remote: Total 134 (delta 0), reused 0 (delta 0), pack-reused 134
# Receiving objects: 100% (134/134), 1.81 MiB | 13.59 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
cd AIND-VUI-Capstone
# Out:
# /content/drive/My Drive/Github/AIND-VUI-Capstone

# %%
# !pip install -r requirements.txt
# Out:
# ...
#     100% |████████████████████████████████| 4.8MB 4.2MB/s
# ...
#     100% |████████████████████████████████| 225kB 18.6MB/s
# ...
#     100% |████████████████████████████████| 1.5MB 11.2MB/s
# ...
#     100% |████████████████████████████████| 6.7MB 4.5MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/ee/09/df/2f10a3b36c903a620183396e24452e7de4dba01861b1d87cea
# done
#   Stored in directory: /root/.cache/pip/wheels/f6/21/55/9c17b30d30ef57e74b50c8824c2bb368d58ddabf9bf8e1fee0
# done
#   Stored in directory: /root/.cache/pip/wheels/89/0e/f6/943a79ae8603092f4effede8f191a0baee3ff241bb6b9dc5c1
# Successfully built keras librosa python-speech-features
# textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.5 which is incompatible.
# magenta 0.3.19 has requirement librosa>=0.6.2, but you'll have librosa 0.5.1 which is incompatible.
# dopamine-rl 1.0.5 has requirement opencv-python>=3.4.1.15, but you'll have opencv-python 3.2.0.7 which is incompatible.
# ...

# %%
# !apt-get install libav-tools
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package libav-tools is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
# However the following packages replace it:
#   ffmpeg
#
# E: Package 'libav-tools' has no installation candidate

# %%
# !wget http://www.openslr.org/resources/12/dev-clean.tar.gz
# !tar -xzvf dev-clean.tar.gz
# !wget http://www.openslr.org/resources/12/test-clean.tar.gz
# !tar -xzvf test-clean.tar.gz
# !mv flac_to_wav.sh LibriSpeech
# Out:
# --2018-12-16 04:57:07--  http://www.openslr.org/resources/12/dev-clean.tar.gz
# Resolving www.openslr.org (www.openslr.org)... 46.101.158.64
# Connecting to www.openslr.org (www.openslr.org)|46.101.158.64|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 337926286 (322M) [application/x-gzip]
# Saving to: ‘dev-clean.tar.gz’
#
# dev-clean.tar.gz    100%[===================>] 322.27M  25.8MB/s    in 14s
#
# 2018-12-16 04:57:21 (22.5 MB/s) - ‘dev-clean.tar.gz’ saved [337926286/337926286]
#
# LibriSpeech/LICENSE.TXT
# LibriSpeech/README.TXT
# LibriSpeech/CHAPTERS.TXT
# LibriSpeech/SPEAKERS.TXT
# LibriSpeech/BOOKS.TXT
# LibriSpeech/dev-clean/
# LibriSpeech/dev-clean/2277/
# LibriSpeech/dev-clean/2277/149896/
# LibriSpeech/dev-clean/2277/149896/2277-149896-0026.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0005.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0033.flac
# LibriSpeech/dev-clean/2277/149896/2277-149896-0006.flac
# ...

# %%
cd LibriSpeech
# Out:
# /content/drive/My Drive/Github/AIND-VUI-Capstone/LibriSpeech

# %%
ls
# Out:
# BOOKS.TXT     dev-clean/      LICENSE.TXT  SPEAKERS.TXT
# CHAPTERS.TXT  flac_to_wav.sh  README.TXT   test-clean/

# %%
import subprocess
 
# Call a bash script
subprocess.call(['./flac_to_wav.sh'])
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-45-8aa8c30402fe> in <module>()
#       2
#       3 # Call a bash script
# ----> 4 subprocess.call(['./flac_to_wav.sh'])
#
# /usr/lib/python3.6/subprocess.py in call(timeout, *popenargs, **kwargs)
#     265     retcode = call(["ls", "-l"])
#     266     """
# --> 267     with Popen(*popenargs, **kwargs) as p:
#     268         try:
#     269             return p.wait(timeout=timeout)
#
# /usr/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     707                                 c2pread, c2pwrite,
#     708                                 errread, errwrite,
# ...

# %%
# !./flac_to_wav.sh
# Out:
# /bin/bash: ./flac_to_wav.sh: Permission denied
